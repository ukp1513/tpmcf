# %%
# First import some things we are gonna need
#import treecorr
import healpy as hp
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy.table import Table
import numpy as np 
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.coordinates import Angle
import pandas as pd

typp = 'all'
times_randoms = 1

# %%
# Open MAP 
# ==========================================
MAP = hp.read_map('dr2_hpix_4096_frac_detection_g.fits.fz')
conv = np.pi/180.
ra_min = -70.0*conv
ra_max = 110.*conv
dec_min = -70.*conv
dec_max = 10.*conv
# ========================
# ========================
rand_ra = np.random.uniform(ra_min, ra_max, 10**7)
rand_sindec = np.random.uniform(np.sin(dec_min), np.sin(dec_max), 10**7)
rand_dec = np.arcsin(rand_sindec)
# ========================

# %%
# Get the healpix indices of the randoms
HP_ind_rand = hp.ang2pix(4096, rand_ra/conv, rand_dec/conv, lonlat=True)

# %%
# Keep only those with randoms for which the value of the des mask 
# ===============================================
# ===============================================
# Keep local mask
# Get a mask - 1 inside the DES mask
DES_mask = np.zeros(len(MAP))
DES_mask[MAP>0] = 1
LOCAL_mask_rand = DES_mask[HP_ind_rand]

# Keep those with LOCAL_mask = 1
rand_ra_pos = rand_ra[LOCAL_mask_rand==1]
rand_dec_pos = rand_dec[LOCAL_mask_rand==1]

ra_angles = Angle(rand_ra_pos, unit=u.rad)
ra_angles_wrap=ra_angles.wrap_at(360.0* u.deg)
dec_angles = Angle(rand_dec_pos, unit=u.rad)

rand_ra_deg = ra_angles_wrap.degree
rand_dec_deg = dec_angles.degree

rand_ID = [i for i in range(len(rand_ra_deg))]
df_rand_full = pd.DataFrame({'ID': rand_ID, 'RA': rand_ra_deg, 'Dec': rand_dec_deg})

# %%
#realdata = Table.read('HSBG_sample_Thuruthipilly+24_v1.fits', format='fits').to_pandas()
#realdata = Table.read('DES_LSB+HSB_concatenatedTable.fits', format='fits').to_pandas()
#realdata = Table.read('DES_LSB+Mid_HSB_concatenatedTable.fits', format='fits').to_pandas()

#realdata.rename(columns = {'COADD_OBJECT_ID':'ID'}, inplace = True)
#realdata['COLOR_G_I']=realdata['MAG_AUTO_G']-realdata['MAG_AUTO_I']

# %%
'''

mucuts = [20.5, 21.0, 21.5, 22.0, 22.5, 23.0, 23.5, 24.0, 24.5]

for mucut in mucuts:

    for type in ['hsb', 'lsb']:
    
        realdata = Table.read('DES_LSB+Mid_HSB_concatenatedTable.fits', format='fits').to_pandas()
        realdata['COLOR_G_I']=realdata['MAG_AUTO_G']-realdata['MAG_AUTO_I']
        
        if(type == 'hsb'):
            realdata = realdata[realdata['MU_MEAN_MODEL_G'] < mucut]
        else:
            realdata = realdata[realdata['MU_MEAN_MODEL_G'] >= mucut]
    
        n_real = len(realdata)
        n_rand = times_randoms*n_real
    
        df_rand_full_sampled = df_rand_full.sample(n_rand)
    
        print("cut: ", mucut, "real: ", n_real, ", random: ", n_rand)
        
        cols_towrite_real = ['COADD_OBJECT_ID','RA','DEC','COLOR_G_I','MU_MEAN_MODEL_G','MAG_AUTO_G','MAG_AUTO_I']
        
        df_subset = realdata[cols_towrite_real]
        
        realdata_nandropped = df_subset.dropna()
        
        realdata_towrite = realdata_nandropped
        
        realdata_towrite.to_csv('real_galaxies_%s_%0.2f' %(type, mucut), sep='\t',columns = cols_towrite_real, index=False, float_format='%f', header=[f'#{x}' if x == cols_towrite_real[0] else x for x in cols_towrite_real])
        
        
        cols_towrite_random = ['ID','RA','Dec']
        df_rand_full_sampled.to_csv('random_galaxies_%s_%0.2f' %(type, mucut), sep='\t',columns = cols_towrite_random, index=False, float_format='%f',header=[f'#{x}' if x == cols_towrite_random[0] else x for x in cols_towrite_random])
'''

# %%
tab = Table.read('DES_LSB+Mid_HSB_concatenatedTable.fits', format='fits').to_pandas()
min_mu = tab['MU_MEAN_MODEL_G'].min()
max_mu = tab['MU_MEAN_MODEL_G'].max()

mucuts = [20.5]#np.arange(min_mu,max_mu,1.0) #[20.5, 21.0, 21.5, 22.0, 22.5, 23.0, 23.5, 24.0, 24.5]

for mucuti in range(len(mucuts)+1):

    
    if(mucuti == 0):
        lowcut = min_mu
        highcut = mucuts[mucuti]
    elif(mucuti == len(mucuts)):
        lowcut = mucuts[-1]
        highcut = max_mu
    else:
        lowcut = mucuts[mucuti-1]
        highcut = mucuts[mucuti]
 

    realdata = Table.read('DES_LSB+Mid_HSB_concatenatedTable.fits', format='fits').to_pandas()
    realdata['COLOR_G_I']=realdata['MAG_AUTO_G']-realdata['MAG_AUTO_I']
    
    realdata = realdata[realdata['MU_MEAN_MODEL_G'] < highcut]
    realdata = realdata[realdata['MU_MEAN_MODEL_G'] >= lowcut]
    
    n_real = len(realdata)
    n_rand = times_randoms*n_real

    df_rand_full_sampled = df_rand_full.sample(150000)

    print("cut: ", lowcut, highcut, "real: ", n_real, ", random: ", n_rand)
    
    cols_towrite_real = ['COADD_OBJECT_ID','RA','DEC','COLOR_G_I','MU_MEAN_MODEL_G','MAG_AUTO_G','MAG_AUTO_I']
    
    df_subset = realdata[cols_towrite_real]
    
    realdata_nandropped = df_subset.dropna()
    
    realdata_towrite = realdata_nandropped
    
    realdata_towrite.to_csv('real_galaxies_%0.2f' %(lowcut), sep='\t',columns = cols_towrite_real, index=False, float_format='%f', header=[f'#{x}' if x == cols_towrite_real[0] else x for x in cols_towrite_real])
    
    
    cols_towrite_random = ['ID','RA','Dec']
    df_rand_full_sampled.to_csv('random_galaxies_%0.2f' %(lowcut), sep='\t',columns = cols_towrite_random, index=False, float_format='%f',header=[f'#{x}' if x == cols_towrite_random[0] else x for x in cols_towrite_random])

# %%
#HSB
#realdata = Table.read('HSBG_sample_Thuruthipilly+24_v1.fits', format='fits').to_pandas()

#LSB
realdata = Table.read('DES_LSB_Sextractor.fits', format='fits').to_pandas()

#LSB+HSB
#realdata = Table.read('DES_LSB+HSB_concatenatedTable.fits', format='fits').to_pandas()

#LSB+Mid
#realdata = Table.read('DES_LSB+Mid.fits', format='fits').to_pandas()


#LSB+Mid+HSB
#realdata = Table.read('DES_LSB+Mid_HSB_concatenatedTable.fits', format='fits').to_pandas()


# magnitude cut

realdata = realdata[realdata['MAG_AUTO_G'] < 19.85]

realdata['COLOR_G_I']=realdata['MAG_AUTO_G']-realdata['MAG_AUTO_I']
    
    
n_real = len(realdata)
n_rand = times_randoms*n_real

df_rand_full_sampled = df_rand_full.sample(150000)

cols_towrite_real = ['COADD_OBJECT_ID','RA','DEC','COLOR_G_I','MU_MEAN_MODEL_G','MAG_AUTO_G','MAG_AUTO_I']

df_subset = realdata[cols_towrite_real]

realdata_nandropped = df_subset.dropna()

realdata_towrite = realdata_nandropped

realdata_towrite.to_csv('real_galaxies', sep='\t',columns = cols_towrite_real, index=False, float_format='%f', header=[f'#{x}' if x == cols_towrite_real[0] else x for x in cols_towrite_real])


cols_towrite_random = ['ID','RA','Dec']
df_rand_full_sampled.to_csv('random_galaxies', sep='\t',columns = cols_towrite_random, index=False, float_format='%f',header=[f'#{x}' if x == cols_towrite_random[0] else x for x in cols_towrite_random])
